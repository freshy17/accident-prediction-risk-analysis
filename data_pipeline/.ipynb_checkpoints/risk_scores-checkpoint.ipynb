# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('new_accident.csv')

# %%
column_mapping = {
    'หน่วยงาน': 'agency',
    'สายทาง': 'road_name',
    'จังหวัด': 'province',
    'รถคันที่1': 'vehicle',
    'บริเวณที่เกิดเหตุ': 'location_type',
    'มูลเหตุสันนิษฐาน': 'presumed_cause',
    'ลักษณะการเกิดเหตุ': 'incident_type',
    'สภาพอากาศ': 'weather',
    'ผู้เสียชีวิต': 'deaths',
    'ผู้บาดเจ็บสาหัส': 'serious_injuries',
    'ผู้บาดเจ็บเล็กน้อย': 'minor_injuries',
    'รวมจำนวนผู้บาดเจ็บ': 'total_injuries',
    'ชั่วโมง': 'hour',
    'LATITUDE' : 'latitude',
    'LONGITUDE' : 'longitude',
    'is_dangerous_7days' : 'is_dangerouse_7days'
}
df2 = df1.rename(columns=column_mapping)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111409 entries, 0 to 111408
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   agency               111409 non-null  object
#  1   road_name            111409 non-null  object
#  2   province             111409 non-null  object
#  3   vehicle              111409 non-null  object
#  4   location_type        111409 non-null  object
#  5   presumed_cause       111409 non-null  object
#  6   incident_type        111409 non-null  object
#  7   weather              111409 non-null  object
#  8   latitude             111409 non-null  float64
#  9   longitude            111409 non-null  float64
#  10  deaths               111409 non-null  int64
#  11  serious_injuries     111409 non-null  int64
#  12  minor_injuries       111409 non-null  int64
#  13  total_injuries       111409 non-null  int64
#  14  hour                 111409 non-null  int64
#  15  year                 111409 non-null  int64
#  16  month                111409 non-null  int64
#  17  day                  111409 non-null  int64
#  18  is_weekend           111409 non-null  int64
#  19  time_period          111409 non-null  object
#  20  severity_level       111409 non-null  object
#  21  is_new_year          111409 non-null  int64
#  22  is_songkran          111409 non-null  int64
#  23  is_dangerouse_7days  111409 non-null  int64
#  24  province_clean       111409 non-null  object
#  25  day_type             111409 non-null  object
# dtypes: float64(2), int64(12), object(12)
# memory usage: 22.1+ MB

# %%
df2 = df2.drop(columns=['day_type'])

# %%
conditions = [
    df2["is_songkran"] == 1,
    df2["is_new_year"] == 1,
    df2["is_dangerouse_7days"] == 1,
    df2["is_weekend"] == 1,
]
choices = ["songkran", "new_year", "danger_7days", "weekend"]
df2["day_type"] = np.select(conditions, choices, default="normal")

# %%
df2.to_csv('new_accident.csv', index=False, encoding='utf-8-sig')
print("บันทึกแล้ว")
# Out:
# บันทึกแล้ว

# %%
df3['risk_score'] = (
    15 + 
    (df2['deaths'] * 25) + 
    (df2['serious_injuries'] * 15) + 
    (df2['minor_injuries'] * 5)
).clip(upper=100)

def assign_risk_level(score):
    if score >= 70:
        return 'High'
    elif score >= 40:
        return 'Medium'
    else:
        return 'Low'

df3['risk_level'] = df3['risk_score'].apply(assign_risk_level)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111409 entries, 0 to 111408
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   agency               111409 non-null  object
#  1   road_name            111409 non-null  object
#  2   province             111409 non-null  object
#  3   vehicle              111409 non-null  object
#  4   location_type        111409 non-null  object
#  5   presumed_cause       111409 non-null  object
#  6   incident_type        111409 non-null  object
#  7   weather              111409 non-null  object
#  8   latitude             111409 non-null  float64
#  9   longitude            111409 non-null  float64
#  10  deaths               111409 non-null  int64
#  11  serious_injuries     111409 non-null  int64
#  12  minor_injuries       111409 non-null  int64
#  13  total_injuries       111409 non-null  int64
#  14  hour                 111409 non-null  int64
#  15  year                 111409 non-null  int64
#  16  month                111409 non-null  int64
#  17  day                  111409 non-null  int64
#  18  is_weekend           111409 non-null  int64
#  19  time_period          111409 non-null  object
#  20  severity_level       111409 non-null  object
#  21  is_new_year          111409 non-null  int64
#  22  is_songkran          111409 non-null  int64
#  23  is_dangerouse_7days  111409 non-null  int64
#  24  province_clean       111409 non-null  object
#  25  day_type             111409 non-null  object
#  26  risk_score           111409 non-null  int64
#  27  risk_level           111409 non-null  object
# dtypes: float64(2), int64(13), object(13)
# memory usage: 23.8+ MB

# %%
df3.to_csv('new_accident2.csv', index=False, encoding='utf-8-sig')
print("บันทึกแล้ว")
# Out:
# บันทึกแล้ว

# %%
df3.head(5)
# Out:
#            agency                                          road_name  \
# 0      กรมทางหลวง                                  ร้อยเอ็ด - หนองดง
# 1  กรมทางหลวงชนบท  แยกทางหลวงหมายเลข 223 (กม.ที่ 11+000) - บ้านด่...
# 2  กรมทางหลวงชนบท  แยกทางหลวงหมายเลข 212 (กม.ที่ 70+535) - บ้านบา...
# 3      กรมทางหลวง                                     ทางรอบเกาะสมุย
# 4      กรมทางหลวง                                 น้ำคลาด - ปางหมิ่น
#
#        province                                vehicle  \
# 0      ร้อยเอ็ด                   รถปิคอัพบรรทุก 4 ล้อ
# 1        สกลนคร                          รถจักรยานยนต์
# 2      มุกดาหาร                          รถจักรยานยนต์
# 3  สุราษฎร์ธานี  รถยนต์นั่งส่วนบุคคล/รถยนต์นั่งสาธารณะ
# 4      พิษณุโลก                          รถจักรยานยนต์
#
#                   location_type           presumed_cause  \
# 0        ทางตรง+ไม่มีความลาดชัน  ขับรถเร็วเกินอัตรากำหนด
# 1        ทางตรง+ไม่มีความลาดชัน                  เมาสุรา
# 2                 ทางสามแยก (Y)                  เมาสุรา
# 3        ทางตรง+ไม่มีความลาดชัน  ขับรถเร็วเกินอัตรากำหนด
# 4  ทางโค้งกว้าง+ไม่มีความลาดชัน  ขับรถเร็วเกินอัตรากำหนด
#
#              incident_type weather   latitude   longitude  ...  is_weekend  \
# 0   พลิกคว่ำ/ตกถนนในทางตรง  แจ่มใส  16.099711  103.799555  ...           0
# 1                  ไม่ระบุ  แจ่มใส  17.094963  104.197741  ...           0
# 2                  ไม่ระบุ  แจ่มใส  16.774523  104.737438  ...           0
# 3                   ชนท้าย  แจ่มใส   9.559068  100.025668  ...           0
# 4  พลิกคว่ำ/ตกถนนในทางโค้ง  แจ่มใส  17.297256  100.408688  ...           0
#
#            time_period                                 severity_level  \
# 0  ดึก (00:00 - 03:59)  รุนแรงน้อย (บาดเจ็บเล็กน้อย/ทรัพย์สินเสียหาย)
# 1  ดึก (00:00 - 03:59)  รุนแรงน้อย (บาดเจ็บเล็กน้อย/ทรัพย์สินเสียหาย)
# 2  ดึก (00:00 - 03:59)  รุนแรงน้อย (บาดเจ็บเล็กน้อย/ทรัพย์สินเสียหาย)
# 3  ดึก (00:00 - 03:59)  รุนแรงน้อย (บาดเจ็บเล็กน้อย/ทรัพย์สินเสียหาย)
# 4  ดึก (00:00 - 03:59)                          รุนแรงมาก (เสียชีวิต)
#
#    is_new_year  is_songkran  is_dangerouse_7days  province_clean  day_type  \
# 0            1            0                    1        ร้อยเอ็ด  new_year
# 1            1            0                    1          สกลนคร  new_year
# 2            1            0                    1        มุกดาหาร  new_year
# 3            1            0                    1    สุราษฎร์ธานี  new_year
# 4            1            0                    1        พิษณุโลก  new_year
#
#    risk_score risk_level
# 0          25        Low
# 1          20        Low
# 2          20        Low
# 3          40     Medium
# 4          70       High
#
# [5 rows x 28 columns]
